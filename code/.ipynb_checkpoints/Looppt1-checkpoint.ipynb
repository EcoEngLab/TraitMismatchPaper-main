# %%
require('ggplot2')
require('nls.multstart')
require('broom')
require('tidyverse')
require('rTPC')
require('dplyr')

rm(list=ls())
graphics.off()
setwd("..//code/")
# Out:
# Loading required package: ggplot2
#
# Loading required package: nls.multstart
#
# Loading required package: broom
#
# Loading required package: tidyverse
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘tidyverse’”
# Loading required package: rTPC
#
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
#take a look at the different models available
get_model_names()
# Out:
#  [1] "beta_2012"             "boatman_2017"          "briere2_1999"
#  [4] "delong_2017"           "flinn_1991"            "gaussian_1987"
#  [7] "hinshelwood_1947"      "joehnk_2008"           "johnsonlewin_1946"
# [10] "kamykowski_1985"       "lactin2_1995"          "modifiedgaussian_2006"
# [13] "oneill_1972"           "pawar_2018"            "quadratic_2008"
# [16] "ratkowsky_1983"        "rezende_2019"          "sharpeschoolfull_1981"
# [19] "sharpeschoolhigh_1981" "sharpeschoollow_1981"  "spain_1982"
# [22] "thomas_2012"           "thomas_2017"           "weibull_1995"

# %%
#read in the trait data
final_trait_data <- read.csv('../data/Final_Traitofinterest.csv')

# %%
#remove completely irrelevant columns
df <- final_trait_data[,colSums(is.na(final_trait_data))<nrow(final_trait_data)]

# %%
#filter to single species and trait
df2 <- dplyr::filter(df, interactor1 == 'Aedes albopictus'& originaltraitname == 'Development Rate')

# %%
#visualize
ggplot(df2, aes(ambienttemp, originaltraitvalue))+
  geom_point()+
  theme_bw(base_size = 12) +
  labs(x = 'Temperature (ºC)',
       y = 'Development Rate',
       title = 'Development Rate across temperatures for Aedes albopictus')
# Out:
# plot without title

# %%
# choose model
mod = 'sharpschoolhigh_1981'

# %%
# get start vals
start_vals <- get_start_vals(df2$ambienttemp, df2$originaltraitvalue, model_name = 'sharpeschoolhigh_1981')

# %%
# get limits
low_lims <- get_lower_lims(df2$ambienttemp, df2$originaltraitvalue, model_name = 'sharpeschoolhigh_1981')
upper_lims <- get_upper_lims(df2$ambienttemp, df2$originaltraitvalue, model_name = 'sharpeschoolhigh_1981')

# %%
start_vals
# Out:
#      r_tref           e          eh          th
#  0.06905828  0.60095423  0.31244305 30.83333333

# %%
low_lims
# Out:
# r_tref      e     eh     th
#      0      0      0      1

# %%
upper_lims
# Out:
#   r_tref        e       eh       th
#  0.16602 10.00000 20.00000 35.00000

# %%
# fit model
fit <- nls_multstart(originaltraitvalue~sharpeschoolhigh_1981(temp = ambienttemp, r_tref,e,eh,th, tref = 15),
                     data = df2,
                     iter = 500,
                     start_lower = start_vals - 10,
                     start_upper = start_vals + 10,
                     lower = low_lims,
                     upper = upper_lims,
                     supp_errors = 'Y')
fit
# Out:
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
#  0.03531  1.44272  1.74738 22.48851
#  residual sum-of-squares: 0.02037
#
# Number of iterations to convergence: 50
# Achieved convergence tolerance: 1.49e-08

# %%
# calculate additional traits
calc_params(fit) %>%
  # round for easy viewing
  mutate_all(round, 2)
# Out:
#   rmax topt  ctmin ctmax e    eh   q10 thermal_safety_margin thermal_tolerance
# 1 0.1  29.35 5.54  Inf   0.65 0.39 2.4 Inf                   Inf
#   breadth skewness
# 1 12.42   0.26

# %%
# predict new data
new_data <- data.frame(ambienttemp = seq(min(df2$ambienttemp), max(df2$ambienttemp), 0.5))
preds <- augment(fit, newdata = new_data)

# %%
#visualize with new line
ggplot(df2, aes(ambienttemp, originaltraitvalue))+
  geom_point()+
  geom_line(aes(ambienttemp, .fitted), preds, col = 'blue') +
  theme_bw(base_size = 12) +
  labs(x = 'Temperature (ºC)',
       y = 'Development Rate',
       title = 'Development Rate across Temperatures for Aedes albopictus')
# Out:
# plot without title

# %%
unique(df$originalid)
# Out:
#   [1] csm1B   csm1E   csm1A   csm1C   csm1D   csm5A   csm5I   csm5B   csm5C
#  [10] csm5D   csm5E   csm5F   csm5G   csm5H   MSS0001 MSS0003 MSS0005 MSS0002
#  [19] MSS0067 MSS0068 MSS0065 MSS0066 csm8I   csm8J   csm8K   csm8L   csm8W
#  [28] csm8X   csm8Y   csm8Z   csm8AA  csm8AB  csm8AC  csm8AD  csm8M   csm8N
#  [37] csm8O   csm8P   csm8Q   csm8AE  csm8A   csm8B   csm8C   csm8D   csm8E
#  [46] csm8F   csm8G   csm8H   csm8R   csm8S   csm8T   csm8U   csm8V   csm2A
#  [55] MTD2084 csm2R   csm2B   csm2C   csm2D   csm2E   csm3F   csm3G   csm3H
#  [64] csm3I   MTD2088 MTD2086 MTD2085 csm2S   csm2J   csm2K   csm2L   csm2M
#  [73] csm2N   csm2O   csm2P   csm2Q   MTD2164 MTD2165 MTD2166 MTD2142 csm4A
#  [82] csm4B   csm4C   csm4D   csm4E   csm4E_2 csm4E_3 csm4E_4 csm4E_5 csm4E_6
#  [91] csm4F   csm4G   csm4H   csm4P   csm4Q   csm4R   csm4S   csm4T   csm4U
# [100] csm4V   csm4W   csm4X   csm4Y   csm4Z   csm4I   csm4J   csm4K   csm4L
# [109] csm4M   csm4N   csm4O   MSS0035 MSS0036 MSS0062 MSS0044 MSS0045 MSS0034
# [118] MSS0049 MSS0053 MSS0054 MSS0048 MSS0043 MSS0059 MSS0033 MSS0050 MSS0051
# [127] MSS0052 MTD2161 MTD2162 MTD2163 MTD2159 MTD2160 MTD2158 MTD2156 MTD2157
# [136] csm6B   csm6C   csm6D   csm6E   csm6F   csm6G   csm6H   csm6I   MTD2119
# [145] MTD2147 MTD2063 MTD2064 MTD2065 MTD2066 MTD2067 MTD2068 MTD2072 MTD2069
# [154] MTD2070 MTD2095 MTD2096 MTD2097 MTD2098 MTD2167 csm7B   csm7C   csm7D
# [163] csm7E   csm7F   csm7G   csm7A   MTD2148 MTD2149 MTD2151 MTD2152 MTD2175
# [172] MTD2176 MTD2177 MTD2178 MTD2179 MTD2180 MTD2187 MTD2188 MTD2189 MTD2190
# [181] MTD2191 MTD2192 MTD2181 MTD2182 MTD2183 MTD2184 MTD2185 MTD2186 MTD2150
# [190] MTD2153 MTD2089 MTD2091 MTD2093 MTD2090 csm7I   csm7J   csm7K   csm7L
# [199] csm7H   MTD2132 MTD2133 MTD2134 MTD2135 MTD2123 MTD2129 MTD2120 MTD2122
# [208] MTD2125 MTD2126 MTD2128 MTD2131 MTD2121 MTD2124 MTD2127 MTD2130
# 215 Levels: csm1A csm1B csm1C csm1D csm1E csm2A csm2B csm2C csm2D ... MTD2192

# %%
#test a loop mean of temperature
shoobop <- list()
for (x in unique(df$originalid)){
  # Subset
  dfsub <- subset(df, df$originalid == x)
  # Apply function
  mean(dfsub$ambienttemp)
  shoobop[[x]] <- print(paste0(x, ": ", mean(dfsub$ambienttemp)))
}
# Out:
# [1] "csm1B: 22.6779166666667"
# [1] "csm1E: 23.0983333333333"
# [1] "csm1A: 23.0983333333333"
# [1] "csm1C: 22.6779166666667"
# [1] "csm1D: 23.0983333333333"
# [1] "csm5A: 23"
# [1] "csm5I: 26.6666666666667"
# [1] "csm5B: 22.5"
# [1] "csm5C: 22.5"
# [1] "csm5D: 25"
# [1] "csm5E: 25"
# [1] "csm5F: 25"
# [1] "csm5G: 25"
# [1] "csm5H: 25"
# [1] "MSS0001: 25"
# [1] "MSS0003: 25"
# [1] "MSS0005: 20"
# [1] "MSS0002: 25"
# [1] "MSS0067: 21.75"
# [1] "MSS0068: 21.75"
# [1] "MSS0065: 24.4"
# [1] "MSS0066: 24.4"
# [1] "csm8I: 25"
# [1] "csm8J: 25"
# [1] "csm8K: 25"
# [1] "csm8L: 25"
# [1] "csm8W: 25"
# [1] "csm8X: 25"
# [1] "csm8Y: 25"
# [1] "csm8Z: 25"
# [1] "csm8AA: 25"
# [1] "csm8AB: 25"
# [1] "csm8AC: 25"
# [1] "csm8AD: 25"
# [1] "csm8M: 15"
# [1] "csm8N: 20"
# [1] "csm8O: 25"
# [1] "csm8P: 30"
# [1] "csm8Q: 35"
# [1] "csm8AE: 25"
# [1] "csm8A: 27.75"
# [1] "csm8B: 25"
# [1] "csm8C: 25"
# [1] "csm8D: 25"
# [1] "csm8E: 25"
# [1] "csm8F: 27.625"
# [1] "csm8G: 25"
# [1] "csm8H: 27.75"
# [1] "csm8R: 15"
# [1] "csm8S: 20"
# [1] "csm8T: 25"
# [1] "csm8U: 30"
# [1] "csm8V: 35"
# [1] "csm2A: 23.72577855"
# [1] "MTD2084: 20"
# [1] "csm2R: 23.75"
# [1] "csm2B: 15"
# [1] "csm2C: 17.5"
# [1] "csm2D: 20"
# [1] "csm2E: 22.5"
# [1] "csm3F: 25"
# [1] "csm3G: 27.5"
# [1] "csm3H: 30"
# [1] "csm3I: 32.5"
# [1] "MTD2088: 20"
# [1] "MTD2086: 20"
# [1] "MTD2085: 20"
# [1] "csm2S: 25"
# [1] "csm2J: 15"
# [1] "csm2K: 17.5"
# [1] "csm2L: 20"
# [1] "csm2M: 22.5"
# [1] "csm2N: 25"
# [1] "csm2O: 27.5"
# [1] "csm2P: 30"
# [1] "csm2Q: 32.5"
# [1] "MTD2164: 28.2"
# [1] "MTD2165: 28.2"
# [1] "MTD2166: 28.2"
# [1] "MTD2142: 24"
# [1] "csm4A: 26"
# [1] "csm4B: 26"
# [1] "csm4C: 24.3333333333333"
# [1] "csm4D: 24.3333333333333"
# [1] "csm4E: 16"
# [1] "csm4E_2: 19"
# [1] "csm4E_3: 22"
# [1] "csm4E_4: 26"
# [1] "csm4E_5: 30"
# [1] "csm4E_6: 33"
# [1] "csm4F: 24.3333333333333"
# [1] "csm4G: 24.3333333333333"
# [1] "csm4H: 26"
# [1] "csm4P: 26"
# [1] "csm4Q: 26"
# [1] "csm4R: 24.3333333333333"
# [1] "csm4S: 24.3333333333333"
# [1] "csm4T: 24.3333333333333"
# [1] "csm4U: 24.3333333333333"
# [1] "csm4V: 26"
# [1] "csm4W: 24.3333333333333"
# [1] "csm4X: 24.3333333333333"
# [1] "csm4Y: 24.3333333333333"
# [1] "csm4Z: 24.3333333333333"
# [1] "csm4I: 26"
# [1] "csm4J: 26"
# [1] "csm4K: 26"
# [1] "csm4L: 26"
# [1] "csm4M: 26"
# [1] "csm4N: 26"
# [1] "csm4O: 26"
# [1] "MSS0035: 25"
# [1] "MSS0036: 25"
# [1] "MSS0062: NA"
# [1] "MSS0044: 24.527027027027"
# [1] "MSS0045: 24.9206349206349"
# [1] "MSS0034: 25"
# [1] "MSS0049: 27.5"
# [1] "MSS0053: 26.5"
# [1] "MSS0054: 27.4"
# [1] "MSS0048: 27.4285714285714"
# [1] "MSS0043: 24.0697674418605"
# [1] "MSS0059: NA"
# [1] "MSS0033: 25"
# [1] "MSS0050: 27.5"
# [1] "MSS0051: 26.5"
# [1] "MSS0052: 27.4"
# [1] "MTD2161: 24.8333333333333"
# [1] "MTD2162: 24.8333333333333"
# [1] "MTD2163: 24.8333333333333"
# [1] "MTD2159: 21.4"
# [1] "MTD2160: 21.4"
# [1] "MTD2158: 21.4"
# [1] "MTD2156: 21.5"
# [1] "MTD2157: 21.5"
# [1] "csm6B: 29.21875"
# [1] "csm6C: 28.75"
# [1] "csm6D: 28.4375"
# [1] "csm6E: 28.4375"
# [1] "csm6F: 28.59375"
# [1] "csm6G: 28.59375"
# [1] "csm6H: 28.59375"
# [1] "csm6I: 28.3585098588235"
# [1] "MTD2119: 22.7166666666667"
# [1] "MTD2147: 21.6"
# [1] "MTD2063: 23.875"
# [1] "MTD2064: 23.875"
# [1] "MTD2065: 25.1428571428571"
# [1] "MTD2066: 25.1428571428571"
# [1] "MTD2067: 25.1428571428571"
# [1] "MTD2068: 25.1428571428571"
# [1] "MTD2072: 25.1428571428571"
# [1] "MTD2069: 25.1428571428571"
# [1] "MTD2070: 25.1428571428571"
# [1] "MTD2095: 22.5"
# [1] "MTD2096: 22.5"
# [1] "MTD2097: 22.5"
# [1] "MTD2098: 22.5"
# [1] "MTD2167: 20.3125"
# [1] "csm7B: 24.558490565"
# [1] "csm7C: 24.575046903"
# [1] "csm7D: 24.639622641"
# [1] "csm7E: 24.607879924"
# [1] "csm7F: 24.596689465"
# [1] "csm7G: 24.594691882"
# [1] "csm7A: 24.598759515"
# [1] "MTD2148: 21.14"
# [1] "MTD2149: 21.14"
# [1] "MTD2151: 21.14"
# [1] "MTD2152: 21.14"
# [1] "MTD2175: 25.3333333333333"
# [1] "MTD2176: 25.3333333333333"
# [1] "MTD2177: 25.3333333333333"
# [1] "MTD2178: 25.3333333333333"
# [1] "MTD2179: 25.3333333333333"
# [1] "MTD2180: 25.3333333333333"
# [1] "MTD2187: 25.3333333333333"
# [1] "MTD2188: 25.3333333333333"
# [1] "MTD2189: 25.3333333333333"
# [1] "MTD2190: 25.3333333333333"
# [1] "MTD2191: 25.3333333333333"
# [1] "MTD2192: 25.3333333333333"
# [1] "MTD2181: 25.3333333333333"
# [1] "MTD2182: 25.3333333333333"
# [1] "MTD2183: 25.3333333333333"
# [1] "MTD2184: 25.3333333333333"
# [1] "MTD2185: 25.3333333333333"
# [1] "MTD2186: 25.3333333333333"
# [1] "MTD2150: 21.14"
# [1] "MTD2153: 21.14"
# [1] "MTD2089: 22.5"
# [1] "MTD2091: 22.5"
# [1] "MTD2093: 20"
# [1] "MTD2090: 22.5"
# [1] "csm7I: 25.8050355790909"
# [1] "csm7J: 25.8504210754545"
# [1] "csm7K: 25.8117472363636"
# [1] "csm7L: 25.7522982027273"
# [1] "csm7H: 25.77212782"
# [1] "MTD2132: 28.3333333333333"
# [1] "MTD2133: 28.3333333333333"
# [1] "MTD2134: 28.3333333333333"
# [1] "MTD2135: 28.3333333333333"
# [1] "MTD2123: 25"
# [1] "MTD2129: 27"
# [1] "MTD2120: 26.4285714285714"
# [1] "MTD2122: 25"
# [1] "MTD2125: 26.4285714285714"
# [1] "MTD2126: 25"
# [1] "MTD2128: 25"
# [1] "MTD2131: 25"
# [1] "MTD2121: 26.4285714285714"
# [1] "MTD2124: 26.4285714285714"
# [1] "MTD2127: 25"
# [1] "MTD2130: 25"

# %%
#start a loop
res <- list()
res2 <- list()
for (x in unique(df$originalid)){
  # Subset
  dfsub <- subset(df, df$originalid == x)
  # get start vals
  start_vals <- get_start_vals(dfsub$ambienttemp, dfsub$originaltraitvalue, model_name = 'sharpeschoolhigh_1981')

  # get limits
  low_lims <- get_lower_lims(dfsub$ambienttemp, dfsub$originaltraitvalue, model_name = 'sharpeschoolhigh_1981')
  upper_lims <- get_upper_lims(dfsub$ambienttemp, dfsub$originaltraitvalue, model_name = 'sharpeschoolhigh_1981')
  
  res[[x]] <-  nls_multstart(originaltraitvalue~sharpeschoolhigh_1981(temp = ambienttemp, r_tref,e,eh,th, tref = 15),
                             data = dfsub,
                             iter = 500,
                             start_lower = start_vals - 10,
                             start_upper = start_vals + 10,
                             lower = low_lims,
                             upper = upper_lims,
                             supp_errors = 'Y')
  res2[[x]] <- calc_params(res[[x]])
  
}

# %%
res
# Out:
# $csm1B
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.4689 10.0000  8.7858 11.3812
#  residual sum-of-squares: 0.4045
#
# Number of iterations to convergence: 47
# Achieved convergence tolerance: 1.49e-08
#
# $csm1E
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
#  0.09169  0.00000  0.41227 22.17511
#  residual sum-of-squares: 0.002868
#
# Number of iterations to convergence: 57
# Achieved convergence tolerance: 1.49e-08
#
# $csm1A
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.7672  2.1275  2.3682 24.6293
#  residual sum-of-squares: 11.95
#
# Number of iterations to convergence: 30
# Achieved convergence tolerance: 1.49e-08
#
# $csm1C
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
# r_tref      e     eh     th
# 55.293  2.597  3.715 16.033
#  residual sum-of-squares: 1483
#
# Number of iterations to convergence: 24
# Achieved convergence tolerance: 1.49e-08
#
# $csm1D
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
# 20.9713  0.4281  2.7236 31.4249
#  residual sum-of-squares: 202.6
#
# Number of iterations to convergence: 21
# Achieved convergence tolerance: 1.49e-08
#
# $csm5A
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
#  0.03531  1.44272  1.74738 22.48851
#  residual sum-of-squares: 0.02037
#
# Number of iterations to convergence: 57
# Achieved convergence tolerance: 1.49e-08
#
# $csm5I
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
# 70.7199  0.1583  0.6358 35.0000
#  residual sum-of-squares: 10419
#
# Number of iterations to convergence: 17
# Achieved convergence tolerance: 1.49e-08
#
# $csm5B
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
# r_tref      e     eh     th
#  9.852  4.206  5.126 19.260
#  residual sum-of-squares: 638.6
#
# Number of iterations to convergence: 37
# Achieved convergence tolerance: 1.49e-08
#
# $csm5C
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
# r_tref      e     eh     th
# 96.300  2.193  2.688 17.020
#  residual sum-of-squares: 4336
#
# Number of iterations to convergence: 25
# Achieved convergence tolerance: 1.49e-08
#
# $csm5D
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
# 100.0000   0.1997   0.9196  35.0000
#  residual sum-of-squares: 44.17
#
# Number of iterations to convergence: 11
# Achieved convergence tolerance: 1.49e-08
#
# $csm5E
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
# 88.4341  0.2184  1.2120 35.0000
#  residual sum-of-squares: 16.96
#
# Number of iterations to convergence: 19
# Achieved convergence tolerance: 1.49e-08
#
# $csm5F
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
# 85.8099  0.1406  2.7883 33.8783
#  residual sum-of-squares: 19.99
#
# Number of iterations to convergence: 15
# Achieved convergence tolerance: 1.49e-08
#
# $csm5G
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
# 83.77357  0.08791  7.52860 32.34962
#  residual sum-of-squares: 1.263
#
# Number of iterations to convergence: 13
# Achieved convergence tolerance: 1.49e-08
#
# $csm5H
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
# 55.8727  0.2756  7.1443 30.9222
#  residual sum-of-squares: 154
#
# Number of iterations to convergence: 18
# Achieved convergence tolerance: 1.49e-08
#
# $MSS0002
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.8440  0.7954  1.6806 21.3596
#  residual sum-of-squares: 0.0004246
#
# Number of iterations to convergence: 12
# Achieved convergence tolerance: 1.49e-08
#
# $MSS0067
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
# 16.2000  0.1775  2.0803 25.3707
#  residual sum-of-squares: 1.614
#
# Number of iterations to convergence: 29
# Achieved convergence tolerance: 1.49e-08
#
# $MSS0065
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
#  0.93908  0.03177 20.00000 32.22276
#  residual sum-of-squares: 0.01126
#
# Number of iterations to convergence: 30
# Achieved convergence tolerance: 1.49e-08
#
# $MSS0066
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.8512  0.0000 20.0000 32.7366
#  residual sum-of-squares: 0.09184
#
# Number of iterations to convergence: 50
# Achieved convergence tolerance: 1.49e-08
#
# $csm8J
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.0224  2.1248  2.3859 23.3071
#  residual sum-of-squares: 0.0001656
#
# Number of iterations to convergence: 24
# Achieved convergence tolerance: 1.49e-08
#
# $csm8A
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#    r_tref         e        eh        th
# 5.664e-01 2.805e-01 2.608e-05 4.500e+01
#  residual sum-of-squares: 1.038
#
# Number of iterations to convergence: 39
# Achieved convergence tolerance: 1.49e-08
#
# $csm8G
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#    r_tref         e        eh        th
#  0.001186  1.760890 20.000000 32.536544
#  residual sum-of-squares: 5.291e-05
#
# Number of iterations to convergence: 24
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2086
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
# 14.78110  0.06281 20.00000 30.00000
#  residual sum-of-squares: 3.609
#
# Number of iterations to convergence: 20
# Achieved convergence tolerance: 1.49e-08
#
# $csm4B
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  9.9836  0.9365  2.0235 33.8012
#  residual sum-of-squares: 5.977
#
# Number of iterations to convergence: 13
# Achieved convergence tolerance: 1.49e-08
#
# $csm4C
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
# 12.8106  0.9833  2.9844 33.0000
#  residual sum-of-squares: 30.68
#
# Number of iterations to convergence: 19
# Achieved convergence tolerance: 1.49e-08
#
# $csm4X
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
# r_tref      e     eh     th
# 19.605  2.371  3.130 25.216
#  residual sum-of-squares: 1176
#
# Number of iterations to convergence: 37
# Achieved convergence tolerance: 1.49e-08
#
# $csm4I
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
# 91.1952  0.2925  0.8838 33.0000
#  residual sum-of-squares: 4.104
#
# Number of iterations to convergence: 10
# Achieved convergence tolerance: 1.49e-08
#
# $csm4K
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
# r_tref      e     eh     th
# 99.802  5.818  5.807 14.964
#  residual sum-of-squares: 1.377
#
# Number of iterations to convergence: 31
# Achieved convergence tolerance: 1.49e-08
#
# $csm4L
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
# 98.6166  0.2796  0.7968 33.0000
#  residual sum-of-squares: 17.73
#
# Number of iterations to convergence: 21
# Achieved convergence tolerance: 1.49e-08
#
# $csm4M
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
# r_tref      e     eh     th
# 97.233  6.432  6.448 15.021
#  residual sum-of-squares: 0.1998
#
# Number of iterations to convergence: 27
# Achieved convergence tolerance: 1.49e-08
#
# $csm4N
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
# r_tref      e     eh     th
# 93.676  2.864  2.931 15.291
#  residual sum-of-squares: 3.799
#
# Number of iterations to convergence: 28
# Achieved convergence tolerance: 1.49e-08
#
# $csm4O
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
# r_tref      e     eh     th
# 11.285  3.276  3.488 19.776
#  residual sum-of-squares: 18.36
#
# Number of iterations to convergence: 29
# Achieved convergence tolerance: 1.49e-08
#
# $MSS0035
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
# r_tref      e     eh     th
#  25.30   0.00   6.34  30.00
#  residual sum-of-squares: 7.969
#
# Number of iterations till stop: 0
# Achieved convergence tolerance: 1.49e-08
# Reason stopped: Improper input parameters.
#
# $MSS0036
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  8.4735  0.6356  8.1826 30.0000
#  residual sum-of-squares: 20.35
#
# Number of iterations till stop: 0
# Achieved convergence tolerance: 1.49e-08
# Reason stopped: Improper input parameters.
#
# $MSS0034
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#    r_tref         e        eh        th
# 7.352e-09 8.192e+00 2.207e+00 4.000e+01
#  residual sum-of-squares: 1001926
#
# Number of iterations to convergence: 33
# Achieved convergence tolerance: 1.49e-08
#
# $MSS0049
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#    r_tref         e        eh        th
# 6.885e-09 8.212e+00 2.962e+00 4.000e+01
#  residual sum-of-squares: 1001061
#
# Number of iterations to convergence: 28
# Achieved convergence tolerance: 1.49e-08
#
# $MSS0048
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#    r_tref         e        eh        th
# 585.88877   0.00000   0.05596  21.90946
#  residual sum-of-squares: 1422398
#
# Number of iterations to convergence: 42
# Achieved convergence tolerance: 1.49e-08
#
# $MSS0033
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
#  0.06184  4.07051  4.96099 20.43153
#  residual sum-of-squares: 0.04445
#
# Number of iterations to convergence: 40
# Achieved convergence tolerance: 1.49e-08
#
# $MSS0050
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
#  0.07614  2.03017  3.61692 26.85331
#  residual sum-of-squares: 0.04335
#
# Number of iterations to convergence: 20
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2119
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#    r_tref         e        eh        th
#  0.009602  1.114805  2.553218 26.780395
#  residual sum-of-squares: 5.786e-06
#
# Number of iterations to convergence: 21
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2147
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
# 18.2412  0.2468  1.5797 23.4328
#  residual sum-of-squares: 13.47
#
# Number of iterations to convergence: 26
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2065
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
# r_tref      e     eh     th
#  6.363 10.000 10.586 16.108
#  residual sum-of-squares: 41.16
#
# Number of iterations till stop: 96
# Achieved convergence tolerance: 1.49e-08
# Reason stopped: Number of calls to `fcn' has reached or exceeded `maxfev' == 500.
#
# $MTD2068
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
# r_tref      e     eh     th
#  0.462 10.000 11.453 17.572
#  residual sum-of-squares: 10.77
#
# Number of iterations to convergence: 42
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2072
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
# r_tref      e     eh     th
#  58.72  10.00  10.34  15.06
#  residual sum-of-squares: 325.3
#
# Number of iterations to convergence: 76
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2070
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.1848 10.0000 10.4207 16.9701
#  residual sum-of-squares: 0.2656
#
# Number of iterations to convergence: 58
# Achieved convergence tolerance: 1.49e-08
#
# $csm7B
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
#  0.07187  0.69937 20.00000 34.36584
#  residual sum-of-squares: 0.007332
#
# Number of iterations to convergence: 23
# Achieved convergence tolerance: 1.49e-08
#
# $csm7C
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.1376  0.9543  6.5919 33.0618
#  residual sum-of-squares: 0.08416
#
# Number of iterations to convergence: 45
# Achieved convergence tolerance: 1.49e-08
#
# $csm7D
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.2437  0.6496 20.0000 34.3681
#  residual sum-of-squares: 0.09905
#
# Number of iterations to convergence: 18
# Achieved convergence tolerance: 1.49e-08
#
# $csm7E
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.2187  0.6407 15.8330 34.2046
#  residual sum-of-squares: 0.06678
#
# Number of iterations to convergence: 27
# Achieved convergence tolerance: 1.49e-08
#
# $csm7F
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.1252  0.6153 20.0000 34.3727
#  residual sum-of-squares: 0.0272
#
# Number of iterations to convergence: 50
# Achieved convergence tolerance: 1.49e-08
#
# $csm7G
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.0946  0.6649 20.0000 34.3621
#  residual sum-of-squares: 0.01059
#
# Number of iterations to convergence: 16
# Achieved convergence tolerance: 1.49e-08
#
# $csm7A
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
# 24.6832  0.9968  3.9153 28.2802
#  residual sum-of-squares: 1760
#
# Number of iterations to convergence: 27
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2175
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
#  0.01738  0.88623  2.46042 32.00000
#  residual sum-of-squares: 1.021e-05
#
# Number of iterations to convergence: 35
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2176
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
#  0.01703  0.85360  2.53522 32.00000
#  residual sum-of-squares: 1.032e-05
#
# Number of iterations to convergence: 15
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2177
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
#  0.01644  0.88191  3.27984 32.00000
#  residual sum-of-squares: 3.019e-05
#
# Number of iterations to convergence: 26
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2178
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
#  0.01645  0.83666  2.99048 32.00000
#  residual sum-of-squares: 3e-05
#
# Number of iterations to convergence: 30
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2179
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
#  0.01916  0.85423  2.12286 32.00000
#  residual sum-of-squares: 2.651e-05
#
# Number of iterations to convergence: 28
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2180
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
#  0.01702  0.86636  2.23947 31.71584
#  residual sum-of-squares: 1.697e-06
#
# Number of iterations to convergence: 43
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2181
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#    r_tref         e        eh        th
# 1.120e-02 5.274e-01 2.257e-07 2.337e+01
#  residual sum-of-squares: 1.011e-05
#
# Number of iterations to convergence: 42
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2091
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.5493  0.9794 12.7042 30.3875
#  residual sum-of-squares: 0.1059
#
# Number of iterations to convergence: 16
# Achieved convergence tolerance: 1.49e-08
#
# $MTD2090
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
# 23.3000  0.2745  1.2270 23.9869
#  residual sum-of-squares: 26.28
#
# Number of iterations to convergence: 16
# Achieved convergence tolerance: 1.49e-08
#
# $csm7I
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#   r_tref        e       eh       th
#  0.07262  0.95862  1.90329 34.74431
#  residual sum-of-squares: 0.000596
#
# Number of iterations to convergence: 20
# Achieved convergence tolerance: 1.49e-08
#
# $csm7J
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.1796  0.6943 20.0000 36.4386
#  residual sum-of-squares: 0.05015
#
# Number of iterations to convergence: 14
# Achieved convergence tolerance: 1.49e-08
#
# $csm7K
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.2067  0.6969 20.0000 36.5182
#  residual sum-of-squares: 0.111
#
# Number of iterations to convergence: 18
# Achieved convergence tolerance: 1.49e-08
#
# $csm7L
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
#  r_tref       e      eh      th
#  0.1781  0.6354 20.0000 36.7022
#  residual sum-of-squares: 0.0503
#
# Number of iterations to convergence: 26
# Achieved convergence tolerance: 1.49e-08
#
# $csm7H
# Nonlinear regression model
#   model: originaltraitvalue ~ sharpeschoolhigh_1981(temp = ambienttemp,     r_tref, e, eh, th, tref = 15)
#    data: data
# r_tref      e     eh     th
#  43.71   0.33  17.63  36.22
#  residual sum-of-squares: 3606
#
# Number of iterations to convergence: 28
# Achieved convergence tolerance: 1.49e-08

# %%
res2
# Out:
# $csm1B
#       rmax  topt  ctmin ctmax          e eh     q10 thermal_safety_margin
# 1 0.283119 40.64 20.446   Inf 0.07954531 NA 1.13736                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf   2.185       NA
#
# $csm1E
#         rmax  topt ctmin ctmax  e       eh q10 thermal_safety_margin
# 1 0.06053395 10.54  -Inf   Inf NA 0.259036  NA                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf   9.592       NA
#
# $csm1A
#       rmax   topt  ctmin ctmax         e eh      q10 thermal_safety_margin
# 1 8.810943 31.832 13.228   Inf 0.7791152 NA 2.765544                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf   7.467       NA
#
# $csm1C
#       rmax   topt ctmin ctmax       e       eh      q10 thermal_safety_margin
# 1 43.57082 17.678 6.361 41.35 3.08105 0.679614 79.79665                23.672
#   thermal_tolerance breadth skewness
# 1            34.989   6.039 2.401436
#
# $csm1D
#       rmax   topt   ctmin  ctmax         e       eh q10 thermal_safety_margin
# 1 34.38751 26.573 -21.515 43.799 0.3388785 0.779153  NA                17.226
#   thermal_tolerance breadth   skewness
# 1            65.314  11.214 -0.4402745
#
# $csm5A
#        rmax   topt ctmin ctmax         e        eh      q10
# 1 0.0967978 29.349 5.536   Inf 0.6526025 0.3927353 2.398066
#   thermal_safety_margin thermal_tolerance breadth  skewness
# 1                   Inf               Inf   12.42 0.2598673
#
# $csm5I
#       rmax   topt ctmin ctmax  e         eh q10 thermal_safety_margin
# 1 61.02007 21.418  -Inf   Inf NA 0.04256902  NA                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf      15       NA
#
# $csm5B
#       rmax   topt ctmin  ctmax        e        eh      q10
# 1 72.52794 21.462 13.32 50.031 2.898039 0.8855309 52.84803
#   thermal_safety_margin thermal_tolerance breadth skewness
# 1                28.569            36.711   5.582 2.012508
#
# $csm5C
#       rmax   topt ctmin  ctmax        e        eh      q10
# 1 110.4173 21.094 6.004 78.768 1.000205 0.4992094 4.030742
#   thermal_safety_margin thermal_tolerance breadth  skewness
# 1                57.674            72.764   10.32 0.5009952
#
# $csm5D
#       rmax   topt ctmin  ctmax  e         eh q10 thermal_safety_margin
# 1 99.85611 23.995  -Inf 80.812 NA 0.08866173  NA                56.817
#   thermal_tolerance breadth skewness
# 1               Inf      20       NA
#
# $csm5E
#       rmax   topt ctmin  ctmax         e eh q10 thermal_safety_margin
# 1 97.63728 25.097  -Inf 66.335 0.0751624 NA  NA                41.238
#   thermal_tolerance breadth skewness
# 1               Inf      20       NA
#
# $csm5F
#       rmax   topt ctmin  ctmax        e eh q10 thermal_safety_margin
# 1 99.52099 25.555  -Inf 43.896 0.100446 NA  NA                18.341
#   thermal_tolerance breadth skewness
# 1               Inf  16.695       NA
#
# $csm5G
#       rmax   topt ctmin  ctmax          e eh q10 thermal_safety_margin
# 1 96.11411 27.679  -Inf 35.644 0.08712038 NA  NA                 7.965
#   thermal_tolerance breadth skewness
# 1               Inf   16.12       NA
#
# $csm5H
#       rmax   topt ctmin ctmax         e eh q10 thermal_safety_margin
# 1 84.82781 27.376  -Inf 34.59 0.2698878 NA  NA                 7.214
#   thermal_tolerance breadth skewness
# 1               Inf   9.889       NA
#
# $MSS0001
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MSS0003
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MSS0005
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MSS0002
#        rmax   topt  ctmin  ctmax  e        eh q10 thermal_safety_margin
# 1 0.8437855 20.884 -9.652 56.177 NA 0.5933684  NA                35.293
#   thermal_tolerance breadth skewness
# 1            65.829  12.097       NA
#
# $MSS0067
#       rmax   topt ctmin  ctmax  e        eh q10 thermal_safety_margin
# 1 15.51305 16.861  -Inf 39.136 NA 0.5667116  NA                22.275
#   thermal_tolerance breadth skewness
# 1               Inf   8.511       NA
#
# $MSS0068
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MSS0065
#        rmax   topt ctmin  ctmax          e eh q10 thermal_safety_margin
# 1 0.9974592 29.655  -Inf 33.419 0.03163078 NA  NA                 3.764
#   thermal_tolerance breadth skewness
# 1               Inf  16.687       NA
#
# $MSS0066
#        rmax   topt ctmin  ctmax  e        eh q10 thermal_safety_margin
# 1 0.8511823 16.803  -Inf 33.929 NA 0.3206624  NA                17.126
#   thermal_tolerance breadth skewness
# 1               Inf  17.178       NA
#
# $csm8I
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8J
#        rmax   topt  ctmin ctmax         e eh      q10 thermal_safety_margin
# 1 0.1743127 30.117 11.933   Inf 0.6915921 NA 2.470066                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf  10.543       NA
#
# $csm8K
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8L
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8W
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8X
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8Y
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8Z
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8AA
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8AB
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8AC
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8AD
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8M
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8N
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8O
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8P
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8Q
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8AE
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8A
#        rmax topt   ctmin ctmax         e eh      q10 thermal_safety_margin
# 1 0.8212444   45 -27.087   Inf 0.2804353 NA 1.451092                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf   6.794       NA
#
# $csm8B
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8C
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8D
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8E
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8F
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8G
#         rmax   topt  ctmin  ctmax        e eh q10 thermal_safety_margin
# 1 0.05140326 31.598 17.956 34.011 1.758536 NA  NA                 2.413
#   thermal_tolerance breadth skewness
# 1            16.055   2.469       NA
#
# $csm8H
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8R
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8S
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8T
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8U
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm8V
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2A
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2084
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2R
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2B
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2C
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2D
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2E
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm3F
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm3G
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm3H
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm3I
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2088
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2086
#       rmax   topt ctmin  ctmax          e eh q10 thermal_safety_margin
# 1 16.39918 27.735  -Inf 31.184 0.05799566 NA  NA                 3.449
#   thermal_tolerance breadth skewness
# 1               Inf  19.486       NA
#
# $MTD2085
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2S
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2J
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2K
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2L
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2M
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2N
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2O
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2P
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm2Q
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2164
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2165
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2166
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2142
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4A
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4B
#       rmax   topt ctmin  ctmax         e eh q10 thermal_safety_margin
# 1 50.39813 33.204 4.849 64.052 0.5982609 NA  NA                30.848
#   thermal_tolerance breadth skewness
# 1            59.203   8.349       NA
#
# $csm4C
#       rmax   topt ctmin  ctmax         e eh q10 thermal_safety_margin
# 1 69.69307 31.089 5.825 48.372 0.7629347 NA  NA                17.283
#   thermal_tolerance breadth skewness
# 1            42.547   6.142       NA
#
# $csm4D
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4E
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4E_2
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4E_3
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4E_4
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4E_5
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4E_6
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4F
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4G
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4H
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4P
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4Q
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4R
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4S
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4T
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4U
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4V
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4W
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4X
#       rmax   topt  ctmin  ctmax        e eh      q10 thermal_safety_margin
# 1 296.1007 28.036 14.182 66.025 1.450967 NA 6.861759                37.989
#   thermal_tolerance breadth skewness
# 1            51.843   8.255       NA
#
# $csm4Y
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4Z
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4I
#       rmax   topt ctmin ctmax          e eh q10 thermal_safety_margin
# 1 96.58927 26.696  -Inf   Inf 0.08109989 NA  NA                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf      14       NA
#
# $csm4J
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm4K
#       rmax topt ctmin ctmax          e eh q10 thermal_safety_margin
# 1 99.46345   33 11.42   Inf 0.02771491 NA  NA                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf      14       NA
#
# $csm4L
#       rmax   topt ctmin ctmax          e eh q10 thermal_safety_margin
# 1 99.99624 26.891  -Inf   Inf 0.01231525 NA  NA                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf      14       NA
#
# $csm4M
#       rmax   topt ctmin ctmax  e         eh q10 thermal_safety_margin
# 1 97.36844 21.812 11.76   Inf NA 0.01471886  NA                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf      14       NA
#
# $csm4N
#       rmax   topt ctmin ctmax  e         eh q10 thermal_safety_margin
# 1 94.41734 24.799 7.823   Inf NA 0.05179038  NA                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf      14       NA
#
# $csm4O
#      rmax   topt  ctmin ctmax  e        eh q10 thermal_safety_margin
# 1 77.1458 25.708 12.743   Inf NA 0.1344428  NA                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf  11.783       NA
#
# $MSS0035
#       rmax topt ctmin  ctmax  e       eh q10 thermal_safety_margin
# 1 25.29356   20  -Inf 33.725 NA 0.283826  NA                13.725
#   thermal_tolerance breadth skewness
# 1               Inf   8.279       NA
#
# $MSS0036
#       rmax   topt  ctmin  ctmax  e eh q10 thermal_safety_margin
# 1 22.87502 27.623 -5.975 33.446 NA NA  NA                 5.823
#   thermal_tolerance breadth skewness
# 1            39.421   5.598       NA
#
# $MSS0062
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MSS0044
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MSS0045
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MSS0034
#       rmax topt  ctmin ctmax        e eh q10 thermal_safety_margin
# 1 999.9672   40 36.582   Inf 7.890767 NA  NA                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf   0.265       NA
#
# $MSS0049
#       rmax topt  ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1 999.9371   40 36.504   Inf NA NA  NA                   Inf               Inf
#   breadth skewness
# 1   0.278       NA
#
# $MSS0053
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MSS0054
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MSS0048
#       rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1 300.6698   15  -Inf   Inf NA NA  NA                   Inf               Inf
#   breadth skewness
# 1      25       NA
#
# $MSS0043
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MSS0059
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MSS0033
#        rmax   topt  ctmin  ctmax        e        eh q10 thermal_safety_margin
# 1 0.8010335 22.725 14.259 52.537 4.344308 0.8400442  NA                29.812
#   thermal_tolerance breadth skewness
# 1            38.278   5.736 3.504264
#
# $MSS0050
#        rmax   topt  ctmin  ctmax        e       eh      q10
# 1 0.9690395 27.383 13.406 46.022 1.706327 1.353674 9.780102
#   thermal_safety_margin thermal_tolerance breadth  skewness
# 1                18.639            32.616   6.078 0.3526537
#
# $MSS0051
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MSS0052
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2161
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2162
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2163
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2159
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2160
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2158
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2156
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2157
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm6B
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm6C
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm6D
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm6E
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm6F
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm6G
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm6H
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm6I
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2119
#         rmax   topt ctmin  ctmax         e eh      q10 thermal_safety_margin
# 1 0.02821002 26.008 3.191 48.022 0.6667231 NA 2.441431                22.014
#   thermal_tolerance breadth skewness
# 1            44.831    8.45       NA
#
# $MTD2147
#     rmax   topt ctmin  ctmax  e        eh q10 thermal_safety_margin
# 1 15.687 15.552  -Inf 44.203 NA 0.6160325  NA                28.651
#   thermal_tolerance breadth skewness
# 1               Inf    7.91       NA
#
# $MTD2063
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2064
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2065
#       rmax   topt  ctmin  ctmax  e        eh q10 thermal_safety_margin
# 1 23.99768 18.054 13.835 61.879 NA 0.5941466  NA                43.825
#   thermal_tolerance breadth skewness
# 1            48.044   3.588       NA
#
# $MTD2066
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2067
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2068
#      rmax   topt  ctmin  ctmax  e       eh q10 thermal_safety_margin
# 1 11.1208 18.804 15.144 35.577 NA 1.435141  NA                16.773
#   thermal_tolerance breadth skewness
# 1            20.433   2.609       NA
#
# $MTD2072
#      rmax topt  ctmin ctmax  e       eh q10 thermal_safety_margin
# 1 54.5441   18 12.847   Inf NA 0.332167  NA                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf   5.208       NA
#
# $MTD2069
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2070
#       rmax   topt  ctmin ctmax  e       eh q10 thermal_safety_margin
# 1 2.402084 19.193 14.717   Inf NA 0.415864  NA                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf   5.924       NA
#
# $MTD2095
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2096
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2097
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2098
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2167
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $csm7B
#        rmax     topt    ctmin    ctmax         e eh      q10
# 1 0.3637519 33.01944 1.589436 35.68444 0.6960465 NA 2.485574
#   thermal_safety_margin thermal_tolerance breadth skewness
# 1                 2.665            34.095   3.945       NA
#
# $csm7C
#        rmax    topt  ctmin   ctmax         e       eh      q10
# 1 0.8773859 30.8996 6.6726 38.0016 0.9795154 2.570715 3.631668
#   thermal_safety_margin thermal_tolerance breadth  skewness
# 1                 7.102            31.329   4.983 -1.591199
#
# $csm7D
#       rmax   topt  ctmin ctmax         e eh      q10 thermal_safety_margin
# 1 1.096185 32.991 -0.552 35.68 0.6468953 NA 2.330138                 2.689
#   thermal_tolerance breadth skewness
# 1            36.232   4.157       NA
#
# $csm7E
#        rmax     topt     ctmin    ctmax         e eh      q10
# 1 0.9252037 32.58527 -1.538734 35.90027 0.6329224 NA 2.290014
#   thermal_safety_margin thermal_tolerance breadth skewness
# 1                 3.315            37.439    4.72       NA
#
# $csm7F
#        rmax     topt    ctmin    ctmax         e eh      q10
# 1 0.5194877 32.97257 -2.19943 35.67957 0.6134331 NA 2.233542
#   thermal_safety_margin thermal_tolerance breadth skewness
# 1                 2.707            37.879   4.323       NA
#
# $csm7G
#        rmax     topt     ctmin    ctmax         e eh      q10
# 1 0.4410545 32.99508 0.1230813 35.67608 0.6621988 NA 2.377945
#   thermal_safety_margin thermal_tolerance breadth skewness
# 1                 2.681            35.553   4.099       NA
#
# $csm7A
#       rmax     topt    ctmin    ctmax        e       eh      q10
# 1 82.01744 26.14671 2.658713 38.13371 0.942106 1.838388 3.579487
#   thermal_safety_margin thermal_tolerance breadth   skewness
# 1                11.987            35.475   6.367 -0.8962825
#
# $MTD2148
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2149
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2151
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2152
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2175
#         rmax   topt ctmin  ctmax         e eh      q10 thermal_safety_margin
# 1 0.06598005 30.137 2.177 51.798 0.5806047 NA 2.132085                21.661
#   thermal_tolerance breadth skewness
# 1            49.621   6.761       NA
#
# $MTD2176
#         rmax   topt ctmin  ctmax         e eh      q10 thermal_safety_margin
# 1 0.06098847 29.868 1.264 50.373 0.6402378 NA 2.329695                20.505
#   thermal_tolerance breadth skewness
# 1            49.109   7.015       NA
#
# $MTD2177
#         rmax   topt ctmin ctmax         e eh      q10 thermal_safety_margin
# 1 0.06639946 29.572 2.552 44.45 0.6804857 NA 2.458199                14.878
#   thermal_tolerance breadth skewness
# 1            41.898   6.663       NA
#
# $MTD2178
#         rmax   topt ctmin  ctmax        e eh      q10 thermal_safety_margin
# 1 0.05939515 29.483 1.038 45.972 0.657797 NA 2.386739                16.489
#   thermal_tolerance breadth skewness
# 1            44.934   7.063       NA
#
# $MTD2179
#         rmax   topt ctmin ctmax         e eh      q10 thermal_safety_margin
# 1 0.06634777 30.512 1.004 57.13 0.5521011 NA 2.055971                26.618
#   thermal_tolerance breadth skewness
# 1            56.126   6.955       NA
#
# $MTD2180
#         rmax   topt ctmin  ctmax         e eh     q10 thermal_safety_margin
# 1 0.05910505 30.077 1.229 54.684 0.5297552 NA 1.99513                24.607
#   thermal_tolerance breadth skewness
# 1            53.455   7.144       NA
#
# $MTD2187
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2188
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2189
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2190
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2191
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2192
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2181
#        rmax topt  ctmin ctmax         e eh      q10 thermal_safety_margin
# 1 0.0182784   32 -7.664   Inf 0.5274459 NA 1.979671                   Inf
#   thermal_tolerance breadth skewness
# 1               Inf   3.358       NA
#
# $MTD2182
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2183
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2184
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2185
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2186
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2150
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2153
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2089
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2091
#       rmax   topt ctmin  ctmax         e eh      q10 thermal_safety_margin
# 1 3.089844 28.843 6.002 32.599 0.9792263 NA 3.749753                 3.756
#   thermal_tolerance breadth skewness
# 1            26.597    3.62       NA
#
# $MTD2093
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2090
#      rmax   topt ctmin  ctmax  e        eh q10 thermal_safety_margin
# 1 19.1274 16.464  -Inf 55.024 NA 0.3395328  NA                 38.56
#   thermal_tolerance breadth skewness
# 1               Inf  15.267       NA
#
# $csm7I
#        rmax     topt    ctmin    ctmax         e eh      q10
# 1 0.4314008 34.80744 6.215442 70.34044 0.6548548 NA 2.335756
#   thermal_safety_margin thermal_tolerance breadth skewness
# 1                35.533            64.125   8.981       NA
#
# $csm7J
#       rmax     topt   ctmin    ctmax         e eh      q10
# 1 1.070333 35.07127 3.02127 37.77527 0.6914807 NA 2.445203
#   thermal_safety_margin thermal_tolerance breadth skewness
# 1                 2.704            34.754   4.038       NA
#
# $csm7K
#       rmax    topt    ctmin   ctmax         e eh      q10 thermal_safety_margin
# 1 1.248557 35.1513 3.184296 37.8563 0.6923216 NA 2.449312                 2.705
#   thermal_tolerance breadth skewness
# 1            34.672   4.039       NA
#
# $csm7L
#       rmax     topt     ctmin    ctmax         e eh      q10
# 1 0.928147 35.29437 0.5203676 38.03537 0.6222923 NA 2.243338
#   thermal_safety_margin thermal_tolerance breadth skewness
# 1                 2.741            37.515   4.409       NA
#
# $csm7H
#       rmax     topt     ctmin    ctmax         e eh q10 thermal_safety_margin
# 1 99.06335 34.37737 -25.65363 37.68037 0.3271939 NA  NA                 3.303
#   thermal_tolerance breadth skewness
# 1            63.334   7.325       NA
#
# $MTD2132
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2133
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2134
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2135
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2123
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2129
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2120
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2122
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2125
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2126
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2128
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2131
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2121
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2124
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2127
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
#
# $MTD2130
#   rmax topt ctmin ctmax  e eh q10 thermal_safety_margin thermal_tolerance
# 1   NA   NA    NA    NA NA NA  NA                    NA                NA
#   breadth skewness
# 1      NA       NA
